# %%
import json

# Read just the first few lines to see the structure
with open('../data/fire_archive_J1V-C2_671381.json', 'r') as f:
    first_lines = [next(f) for _ in range(200)]
    for i, line in enumerate(first_lines):
        print(f"Line {i+1}: {line[:100]}")  # Print first 10 chars
# Out:
# Line 1: [
#
# Line 2:     {
#
# Line 3:         "latitude": 37.21312,
#
# Line 4:         "longitude": 15.16676,
#
# Line 5:         "acq_date": "2024-01-01",
#
# Line 6:         "acq_time": "0000",
#
# Line 7:         "version": "2",
#
# Line 8:         "bright_t31": 285.21,
#
# Line 9:         "instrument": "VIIRS",
#
# Line 10:         "brightness": 298.64,
#
# Line 11:         "scan": 0.44,
#
# Line 12:         "daynight": "N",
#
# Line 13:         "type": "2",
#
# Line 14:         "confidence": "n",
#
# Line 15:         "frp": 1.13,
#
# Line 16:         "satellite": "N20",
#
# Line 17:         "track": 0.62
#
# Line 18:     },
#
# Line 19:     {
#
# Line 20:         "latitude": 37.44418,
#
# Line 21:         "longitude": 15.08109,
#
# Line 22:         "acq_date": "2024-01-01",
#
# Line 23:         "acq_time": "0000",
#
# Line 24:         "version": "2",
#
# Line 25:         "bright_t31": 280.31,
#
# Line 26:         "instrument": "VIIRS",
#
# ...
